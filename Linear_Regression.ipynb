# %% [markdown]
# <a href="https://colab.research.google.com/github/dprobity/machinelearning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame

from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('/content/cost_revenue_clean.csv')

data.tail()
# Out:
#       production_budget_usd  worldwide_gross_usd
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
x = data['production_budget_usd']
y = data['worldwide_gross_usd']

# %%
x = DataFrame(x)
y = DataFrame(y)

#y.head()

# %%
plt.figure(figsize=(10, 4))
plt.scatter(x, y, alpha=0.5)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
regression = LinearRegression()

# %%
regression.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# slope coefficient

# %%
regression.coef_            # theta_1
# Out:
# array([[3.11150918]])

# %%
regression.intercept_         # the intercept
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(10, 4))
plt.scatter(x, y, alpha=0.5)
plt.plot(x, regression.predict(x), color='red', linewidth=4)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# Checking the gooodness of fit

# %%
regression.score(x, y)
# Out:
# 0.5496485356985729

# %% [markdown]
# what will happen if this model is trained on more features?
